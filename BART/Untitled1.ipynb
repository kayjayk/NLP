# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU에 1GB 메모리만 할당하도록 제한
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=2500)])
  except RuntimeError as e:
    # 프로그램 시작시에 가상 장치가 설정되어야만 합니다
    print(e)

# %%
import re
import pickle
import random

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## data load

# %%
# read pickle file
pickle_in = open("../Data/plots_text.pickle","rb")
movie_plots = pickle.load(pickle_in)

# count of movie plot summaries
len(movie_plots)
# Out:
# 500

# %%
movie_plots[0]
# Out:
# 'barry is a private with the 101st airborne division of the united states army, stationed at fort campbell, kentucky. calpernia works as a showgirl at a transgender revue in nashville, tennessee when the two met in 1999. barry\'s roommate justin fisher  brings barry to the club where she performs. when barry and calpernia begin seeing each other regularly, fisher begins spreading rumors on base about their relationship, which appeared to be a violation of the military\'s "don\'t ask, don\'t tell" policy about discussing the sexual orientation of military personnel. barry faces increasing harassment and pressure, which explode into violence over fourth of july weekend. while calpernia performs in a pageant in nashville, barry is beaten to death in his sleep with a baseball bat by calvin glover, who had been goaded by fisher into committing the crime. the film ends with a discussion of the aftermath.'

# %% [markdown]
# ## data preparation

# %%
movie_plots = [re.sub("[^a-z' ]", "", i) for i in movie_plots]

# %%
# create sequences of length 5 tokens
def create_seq(text, seq_len = 5):
    
    sequences = []

    # if the number of tokens in 'text' is greater than 5
    if len(text.split()) > seq_len:
      for i in range(seq_len, len(text.split())):
        # select sequence of tokens
        seq = text.split()[i-seq_len:i+1]
        # add to the list
        sequences.append(" ".join(seq))

      return sequences

    # if the number of tokens in 'text' is less than or equal to 5
    else:
      
      return [text]

# %%
seqs = [create_seq(i) for i in movie_plots]

# merge list-of-lists into a single list
seqs = sum(seqs, [])

# count of sequences
len(seqs)
# Out:
# 152644

# %%
print(seqs[0])
print(seqs[1])
print(seqs[2])
print(seqs[3])
# Out:
# barry is a private with the
# is a private with the st
# a private with the st airborne
# private with the st airborne division

# %% [markdown]
# * split them into input and target sequences

# %%
# create inputs and targets (x and y)
x = []
y = []

for s in seqs:
  x.append(" ".join(s.split()[:-1]))
  y.append(" ".join(s.split()[1:]))

# %%
x
# Out:
# ['barry is a private with',
#  'is a private with the',
#  'a private with the st',
#  'private with the st airborne',
#  'with the st airborne division',
#  'the st airborne division of',
#  'st airborne division of the',
#  'airborne division of the united',
#  'division of the united states',
#  'of the united states army',
#  'the united states army stationed',
#  'united states army stationed at',
#  'states army stationed at fort',
#  'army stationed at fort campbell',
#  'stationed at fort campbell kentucky',
#  'at fort campbell kentucky calpernia',
#  'fort campbell kentucky calpernia works',
#  'campbell kentucky calpernia works as',
#  'kentucky calpernia works as a',
#  'calpernia works as a showgirl',
#  'works as a showgirl at',
#  'as a showgirl at a',
#  'a showgirl at a transgender',
#  'showgirl at a transgender revue',
#  'at a transgender revue in',
#  'a transgender revue in nashville',
#  'transgender revue in nashville tennessee',
#  'revue in nashville tennessee when',
#  'in nashville tennessee when the',
#  'nashville tennessee when the two',
#  'tennessee when the two met',
#  'when the two met in',
#  "the two met in barry's",
#  "two met in barry's roommate",
#  "met in barry's roommate justin",
#  "in barry's roommate justin fisher",
#  "barry's roommate justin fisher brings",
#  'roommate justin fisher brings barry',
#  'justin fisher brings barry to',
#  'fisher brings barry to the',
#  'brings barry to the club',
#  'barry to the club where',
#  'to the club where she',
#  'the club where she performs',
#  'club where she performs when',
#  'where she performs when barry',
#  'she performs when barry and',
#  'performs when barry and calpernia',
#  'when barry and calpernia begin',
#  'barry and calpernia begin seeing',
#  'and calpernia begin seeing each',
#  'calpernia begin seeing each other',
#  'begin seeing each other regularly',
#  'seeing each other regularly fisher',
#  'each other regularly fisher begins',
#  'other regularly fisher begins spreading',
#  'regularly fisher begins spreading rumors',
#  'fisher begins spreading rumors on',
#  'begins spreading rumors on base',
#  'spreading rumors on base about',
#  'rumors on base about their',
#  'on base about their relationship',
#  'base about their relationship which',
#  'about their relationship which appeared',
#  'their relationship which appeared to',
#  'relationship which appeared to be',
#  'which appeared to be a',
#  'appeared to be a violation',
#  'to be a violation of',
#  'be a violation of the',
#  "a violation of the military's",
#  "violation of the military's don't",
#  "of the military's don't ask",
#  "the military's don't ask don't",
#  "military's don't ask don't tell",
#  "don't ask don't tell policy",
#  "ask don't tell policy about",
#  "don't tell policy about discussing",
#  'tell policy about discussing the',
#  'policy about discussing the sexual',
#  'about discussing the sexual orientation',
#  'discussing the sexual orientation of',
#  'the sexual orientation of military',
#  'sexual orientation of military personnel',
#  'orientation of military personnel barry',
#  'of military personnel barry faces',
#  'military personnel barry faces increasing',
#  'personnel barry faces increasing harassment',
#  'barry faces increasing harassment and',
#  'faces increasing harassment and pressure',
#  'increasing harassment and pressure which',
#  'harassment and pressure which explode',
#  'and pressure which explode into',
#  'pressure which explode into violence',
#  'which explode into violence over',
#  'explode into violence over fourth',
#  'into violence over fourth of',
#  'violence over fourth of july',
#  'over fourth of july weekend',
#  'fourth of july weekend while',
#  'of july weekend while calpernia',
#  'july weekend while calpernia performs',
#  'weekend while calpernia performs in',
#  'while calpernia performs in a',
#  'calpernia performs in a pageant',
#  'performs in a pageant in',
#  'in a pageant in nashville',
#  'a pageant in nashville barry',
#  'pageant in nashville barry is',
#  'in nashville barry is beaten',
#  'nashville barry is beaten to',
#  'barry is beaten to death',
#  'is beaten to death in',
#  'beaten to death in his',
#  'to death in his sleep',
#  'death in his sleep with',
#  'in his sleep with a',
#  'his sleep with a baseball',
#  'sleep with a baseball bat',
#  'with a baseball bat by',
#  'a baseball bat by calvin',
#  'baseball bat by calvin glover',
#  'bat by calvin glover who',
#  'by calvin glover who had',
#  'calvin glover who had been',
#  'glover who had been goaded',
#  'who had been goaded by',
#  'had been goaded by fisher',
#  'been goaded by fisher into',
#  'goaded by fisher into committing',
#  'by fisher into committing the',
#  'fisher into committing the crime',
#  'into committing the crime the',
#  'committing the crime the film',
#  'the crime the film ends',
#  'crime the film ends with',
#  'the film ends with a',
#  'film ends with a discussion',
#  'ends with a discussion of',
#  'with a discussion of the',
#  'chinese exorcist oneeyebrow priest leads',
#  'exorcist oneeyebrow priest leads a',
#  'oneeyebrow priest leads a peaceful',
#  'priest leads a peaceful life',
#  'leads a peaceful life with',
#  'a peaceful life with two',
#  'peaceful life with two disciples',
#  'life with two disciples ah',
#  'with two disciples ah hao',
#  'two disciples ah hao and',
#  'disciples ah hao and ah',
#  'ah hao and ah fang',
#  'hao and ah fang in',
#  'and ah fang in a',
#  'ah fang in a small',
#  'fang in a small town',
#  'in a small town together',
#  'a small town together with',
#  'small town together with a',
#  'town together with a naughty',
#  'together with a naughty mini',
#  'with a naughty mini vampire',
#  'a naughty mini vampire while',
#  'naughty mini vampire while finding',
#  'mini vampire while finding new',
#  'vampire while finding new water',
#  'while finding new water sources',
#  'finding new water sources one',
#  'new water sources one day',
#  'water sources one day the',
#  'sources one day the priest',
#  'one day the priest encounters',
#  'day the priest encounters a',
#  'the priest encounters a european',
#  'priest encounters a european vampire',
#  'encounters a european vampire in',
#  'a european vampire in the',
#  'european vampire in the nearby',
#  'vampire in the nearby church',
#  'in the nearby church who',
#  'the nearby church who is',
#  'nearby church who is aided',
#  'church who is aided by',
#  'who is aided by a',
#  'is aided by a dead',
#  'aided by a dead countess',
#  'by a dead countess although',
#  'a dead countess although the',
#  'dead countess although the priest',
#  'countess although the priest manages',
#  'although the priest manages to',
#  'the priest manages to get',
#  'priest manages to get rid',
#  'manages to get rid of',
#  'to get rid of the',
#  'get rid of the countess',
#  'rid of the countess his',
#  'of the countess his chinese',
#  'the countess his chinese exorcism',
#  'countess his chinese exorcism fails',
#  'his chinese exorcism fails on',
#  'chinese exorcism fails on the',
#  'exorcism fails on the european',
#  'while playing baseball on a',
#  'playing baseball on a busy',
#  'baseball on a busy street',
#  'on a busy street in',
#  'a busy street in greenpoint',
#  'busy street in greenpoint mickey',
#  'street in greenpoint mickey is',
#  'in greenpoint mickey is struck',
#  'greenpoint mickey is struck by',
#  'mickey is struck by a',
#  'is struck by a car',
#  'struck by a car though',
#  'by a car though he',
#  'a car though he fully',
#  'car though he fully recovers',
#  'though he fully recovers from',
#  'he fully recovers from his',
#  'fully recovers from his injuries',
#  'recovers from his injuries mickey',
#  'from his injuries mickey meets',
#  'his injuries mickey meets several',
#  'injuries mickey meets several other',
#  'mickey meets several other kids',
#  'meets several other kids in',
#  'several other kids in the',
#  'other kids in the hospital',
#  'kids in the hospital who',
#  "in the hospital who weren't",
#  "the hospital who weren't so",
#  "hospital who weren't so lucky",
#  "who weren't so lucky instantly",
#  "weren't so lucky instantly developing",
#  'so lucky instantly developing a',
#  'lucky instantly developing a sense',
#  'instantly developing a sense of',
#  'developing a sense of civic',
#  'a sense of civic responsibility',
#  'sense of civic responsibility the',
#  'of civic responsibility the gang',
#  'civic responsibility the gang members',
#  'responsibility the gang members establish',
#  'the gang members establish the',
#  'gang members establish the go',
#  'members establish the go safety',
#  'establish the go safety society',
#  'the go safety society dedicated',
#  'go safety society dedicated to',
#  'safety society dedicated to lowering',
#  'society dedicated to lowering the',
#  'dedicated to lowering the number',
#  'to lowering the number of',
#  'lowering the number of auto',
#  'the number of auto injuries',
#  'number of auto injuries in',
#  'of auto injuries in their',
#  'auto injuries in their communityref',
#  'injuries in their communityref namehttpmoviesnytimescommoviegooverview',
#  'in their communityref namehttpmoviesnytimescommoviegooverview titleworkny',
#  'thadeous and fabious danny mcbride',
#  'and fabious danny mcbride are',
#  'fabious danny mcbride are sons',
#  'danny mcbride are sons of',
#  'mcbride are sons of king',
#  'are sons of king tallious',
#  'sons of king tallious they',
#  'of king tallious they are',
#  'king tallious they are warriors',
#  'tallious they are warriors fabious',
#  'they are warriors fabious is',
#  'are warriors fabious is dashing',
#  'warriors fabious is dashing and',
#  'fabious is dashing and skilled',
#  'is dashing and skilled and',
#  'dashing and skilled and thadeous',
#  'and skilled and thadeous is',
#  'skilled and thadeous is lazy',
#  'and thadeous is lazy and',
#  'thadeous is lazy and ineffectual',
#  'is lazy and ineffectual while',
#  'lazy and ineffectual while celebrating',
#  'and ineffectual while celebrating his',
#  'ineffectual while celebrating his latest',
#  'while celebrating his latest victory',
#  'celebrating his latest victory over',
#  'his latest victory over the',
#  'latest victory over the evil',
#  'victory over the evil sorcerer',
#  'over the evil sorcerer who',
#  'the evil sorcerer who has',
#  'evil sorcerer who has been',
#  'sorcerer who has been ravaging',
#  "who has been ravaging tallious's",
#  "has been ravaging tallious's kingdom",
#  "been ravaging tallious's kingdom leezar",
#  "ravaging tallious's kingdom leezar fabious",
#  "tallious's kingdom leezar fabious introduces",
#  'kingdom leezar fabious introduces the',
#  'leezar fabious introduces the virgin',
#  'fabious introduces the virgin belladonna',
#  'introduces the virgin belladonna he',
#  'the virgin belladonna he freed',
#  'virgin belladonna he freed from',
#  'belladonna he freed from a',
#  'he freed from a tower',
#  'freed from a tower and',
#  'from a tower and wishes',
#  'a tower and wishes to',
#  'tower and wishes to marry',
#  'and wishes to marry her',
#  'wishes to marry her though',
#  'to marry her though he',
#  'marry her though he is',
#  'her though he is made',
#  'though he is made the',
#  'he is made the best',
#  'is made the best man',
#  'made the best man thadeous',
#  'the best man thadeous skips',
#  'best man thadeous skips the',
#  'man thadeous skips the wedding',
#  'thadeous skips the wedding after',
#  'skips the wedding after overhearing',
#  "the wedding after overhearing fabious's",
#  "wedding after overhearing fabious's knights",
#  "after overhearing fabious's knights elite",
#  "overhearing fabious's knights elite led",
#  "fabious's knights elite led by",
#  'knights elite led by boremont',
#  'elite led by boremont talk',
#  'led by boremont talk about',
#  'by boremont talk about him',
#  'boremont talk about him negatively',
#  'talk about him negatively but',
#  'about him negatively but the',
#  'him negatively but the wedding',
#  'negatively but the wedding is',
#  'but the wedding is then',
#  'the wedding is then crashed',
#  'wedding is then crashed by',
#  'is then crashed by leezar',
#  'then crashed by leezar revealing',
#  'crashed by leezar revealing himself',
#  'by leezar revealing himself to',
#  'leezar revealing himself to be',
#  'revealing himself to be the',
#  'himself to be the one',
#  'to be the one who',
#  'be the one who placed',
#  'the one who placed belladona',
#  'one who placed belladona in',
#  'who placed belladona in the',
#  'placed belladona in the tower',
#  'belladona in the tower before',
#  'in the tower before spiriting',
#  'the tower before spiriting her',
#  'tower before spiriting her away',
#  'before spiriting her away returning',
#  'spiriting her away returning to',
#  'her away returning to the',
#  'away returning to the castle',
#  'returning to the castle with',
#  'to the castle with his',
#  'the castle with his servant',
#  'castle with his servant courtney',
#  'with his servant courtney thadeous',
#  'his servant courtney thadeous is',
#  'servant courtney thadeous is forced',
#  'courtney thadeous is forced into',
#  'thadeous is forced into joining',
#  'is forced into joining fabious',
#  'forced into joining fabious on',
#  'into joining fabious on his',
#  'joining fabious on his quest',
#  'fabious on his quest to',
#  'on his quest to rescue',
#  'his quest to rescue belladonna',
#  'quest to rescue belladonna visiting',
#  'to rescue belladonna visiting the',
#  'rescue belladonna visiting the great',
#  'belladonna visiting the great wise',
#  'visiting the great wise wizard',
#  'the great wise wizard thadeous',
#  'great wise wizard thadeous and',
#  'wise wizard thadeous and fabious',
#  'wizard thadeous and fabious learn',
#  'thadeous and fabious learn that',
#  'and fabious learn that leezar',
#  'fabious learn that leezar is',
#  'learn that leezar is attempting',
#  'that leezar is attempting to',
#  'leezar is attempting to fulfill',
#  'is attempting to fulfill a',
#  'attempting to fulfill a prophecy',
#  'to fulfill a prophecy of',
#  'fulfill a prophecy of a',
#  'a prophecy of a warlock',
#  'prophecy of a warlock having',
#  'of a warlock having sex',
#  'a warlock having sex with',
#  'warlock having sex with a',
#  'having sex with a maiden',
#  'sex with a maiden when',
#  'with a maiden when the',
#  'a maiden when the two',
#  'maiden when the two moons',
#  'when the two moons converge',
#  'the two moons converge impregnating',
#  'two moons converge impregnating her',
#  'moons converge impregnating her with',
#  'converge impregnating her with a',
#  'impregnating her with a dragon',
#  'her with a dragon that',
#  'with a dragon that will',
#  'a dragon that will allow',
#  'dragon that will allow him',
#  'that will allow him to',
#  'will allow him to take',
#  'allow him to take over',
#  'him to take over king',
#  "to take over king tallious'",
#  "take over king tallious' kingdom",
#  "over king tallious' kingdom to",
#  "king tallious' kingdom to destroy",
#  "tallious' kingdom to destroy leezar",
#  'kingdom to destroy leezar they',
#  'to destroy leezar they are',
#  'destroy leezar they are given',
#  'leezar they are given a',
#  'they are given a magic',
#  'are given a magic compass',
#  'given a magic compass that',
#  'a magic compass that would',
#  'magic compass that would lead',
#  'compass that would lead them',
#  'that would lead them to',
#  'would lead them to the',
#  'lead them to the blade',
#  'them to the blade of',
#  'to the blade of unicorn',
#  'the blade of unicorn located',
#  'blade of unicorn located within',
#  'of unicorn located within a',
#  'unicorn located within a labyrinth',
#  'located within a labyrinth on',
#  'within a labyrinth on the',
#  'a labyrinth on the way',
#  'labyrinth on the way there',
#  'on the way there they',
#  'the way there they learn',
#  "way there they learn fabious's",
#  "there they learn fabious's slave",
#  "they learn fabious's slave julie",
#  "learn fabious's slave julie has",
#  "fabious's slave julie has been",
#  'slave julie has been reporting',
#  'julie has been reporting to',
#  'has been reporting to leezar',
#  'been reporting to leezar of',
#  'reporting to leezar of their',
#  'to leezar of their progress',
#  'leezar of their progress and',
#  'of their progress and the',
#  'their progress and the knights',
#  'progress and the knights elite',
#  'and the knights elite are',
#  'the knights elite are serving',
#  'knights elite are serving the',
#  'elite are serving the warlock',
#  'are serving the warlock after',
#  'serving the warlock after his',
#  'the warlock after his brother',
#  'warlock after his brother sends',
#  'after his brother sends his',
#  'his brother sends his mechanical',
#  'brother sends his mechanical bird',
#  'sends his mechanical bird simon',
#  'his mechanical bird simon to',
#  'mechanical bird simon to tell',
#  'bird simon to tell the',
#  'simon to tell the king',
#  'to tell the king of',
#  'tell the king of the',
#  'the king of the betrayal',
#  'king of the betrayal by',
#  'of the betrayal by the',
#  'the betrayal by the knights',
#  'betrayal by the knights elite',
#  'by the knights elite and',
#  'the knights elite and request',
#  'knights elite and request reinforcements',
#  'elite and request reinforcements thadeous',
#  'and request reinforcements thadeous fabious',
#  'request reinforcements thadeous fabious and',
#  'reinforcements thadeous fabious and courtney',
#  'thadeous fabious and courtney are',
#  'fabious and courtney are captured',
#  'and courtney are captured by',
#  'courtney are captured by nymphs',
#  'are captured by nymphs under',
#  'captured by nymphs under their',
#  'by nymphs under their leader',
#  'nymphs under their leader marteetee',
#  'under their leader marteetee who',
#  'their leader marteetee who imprisons',
#  'leader marteetee who imprisons them',
#  'marteetee who imprisons them at',
#  'who imprisons them at an',
#  'imprisons them at an arena',
#  'them at an arena where',
#  'at an arena where fabious',
#  'an arena where fabious kills',
#  'arena where fabious kills off',
#  "where fabious kills off marteetee's",
#  "fabious kills off marteetee's finest",
#  "kills off marteetee's finest warrior",
#  "off marteetee's finest warrior in",
#  "marteetee's finest warrior in retaliation",
#  'finest warrior in retaliation marteetee',
#  'warrior in retaliation marteetee summons',
#  'in retaliation marteetee summons his',
#  'retaliation marteetee summons his hydralike',
#  'marteetee summons his hydralike familiar',
#  'summons his hydralike familiar to',
#  'his hydralike familiar to kill',
#  'hydralike familiar to kill them',
#  'familiar to kill them thadeous',
#  'to kill them thadeous and',
#  'kill them thadeous and fabious',
#  'them thadeous and fabious are',
#  'thadeous and fabious are rescued',
#  'and fabious are rescued by',
#  'fabious are rescued by isabel',
#  'are rescued by isabel a',
#  'rescued by isabel a warrior',
#  'by isabel a warrior seeking',
#  'isabel a warrior seeking revenge',
#  'a warrior seeking revenge for',
#  'warrior seeking revenge for her',
#  "seeking revenge for her father's",
#  "revenge for her father's murder",
#  "for her father's murder at",
#  "her father's murder at marteetee's",
#  "father's murder at marteetee's hands",
#  "murder at marteetee's hands later",
#  "at marteetee's hands later that",
#  "marteetee's hands later that night",
#  'hands later that night thadeous',
#  'later that night thadeous learns',
#  'that night thadeous learns that',
#  'night thadeous learns that isabel',
#  'thadeous learns that isabel is',
#  'learns that isabel is also',
#  'that isabel is also after',
#  'isabel is also after leezar',
#  'is also after leezar for',
#  'also after leezar for the',
#  'after leezar for the slaughter',
#  'leezar for the slaughter of',
#  'for the slaughter of her',
#  'the slaughter of her brothers',
#  'slaughter of her brothers the',
#  'of her brothers the next',
#  'her brothers the next day',
#  'brothers the next day the',
#  'the next day the party',
#  'next day the party learn',
#  'day the party learn too',
#  'the party learn too late',
#  'party learn too late that',
#  'learn too late that isabel',
#  'too late that isabel stole',
#  'late that isabel stole the',
#  'that isabel stole the compass',
#  'isabel stole the compass from',
#  'stole the compass from thadeous',
#  'the compass from thadeous fabious',
#  'compass from thadeous fabious decides',
#  'from thadeous fabious decides to',
#  'thadeous fabious decides to find',
#  'fabious decides to find the',
#  'decides to find the blade',
#  'to find the blade of',
#  'find the blade of unicorn',
#  'the blade of unicorn alone',
#  'blade of unicorn alone as',
#  'of unicorn alone as thadeous',
#  'unicorn alone as thadeous and',
#  'alone as thadeous and courtney',
#  'as thadeous and courtney go',
#  'thadeous and courtney go to',
#  'and courtney go to a',
#  'courtney go to a tavern',
#  'go to a tavern where',
#  'to a tavern where they',
#  'a tavern where they find',
#  'tavern where they find isabel',
#  'where they find isabel and',
#  'they find isabel and steal',
#  'find isabel and steal the',
#  'isabel and steal the compass',
#  'and steal the compass back',
#  'steal the compass back but',
#  'the compass back but finding',
#  'compass back but finding that',
#  'back but finding that his',
#  'but finding that his brother',
#  'finding that his brother has',
#  'that his brother has been',
#  'his brother has been captured',
#  'brother has been captured by',
#  "has been captured by leezar's",
#  "been captured by leezar's men",
#  "captured by leezar's men thadeous",
#  "by leezar's men thadeous wins",
#  "leezar's men thadeous wins isabel",
#  'men thadeous wins isabel over',
#  'thadeous wins isabel over as',
#  'wins isabel over as they',
#  'isabel over as they join',
#  'over as they join forces',
#  'as they join forces entering',
#  'they join forces entering the',
#  'join forces entering the labyrinth',
#  'forces entering the labyrinth where',
#  'entering the labyrinth where they',
#  'the labyrinth where they encounter',
#  'labyrinth where they encounter a',
#  'where they encounter a minotaur',
#  'they encounter a minotaur getting',
#  'encounter a minotaur getting separated',
#  'a minotaur getting separated from',
#  'minotaur getting separated from the',
#  'getting separated from the others',
#  'separated from the others thadeous',
#  'from the others thadeous retrieves',
#  'the others thadeous retrieves the',
#  'others thadeous retrieves the blade',
#  'thadeous retrieves the blade of',
#  'retrieves the blade of unicorn',
#  'the blade of unicorn and',
#  'blade of unicorn and slays',
#  'of unicorn and slays the',
#  'unicorn and slays the minotaur',
#  'and slays the minotaur thadeous',
#  'slays the minotaur thadeous and',
#  'the minotaur thadeous and his',
#  'minotaur thadeous and his group',
#  'thadeous and his group make',
#  'and his group make their',
#  'his group make their way',
#  'group make their way to',
#  "make their way to leezar's",
#  "their way to leezar's castle",
#  "way to leezar's castle and",
#  "to leezar's castle and free",
#  "leezar's castle and free fabious",
#  'castle and free fabious while',
#  'and free fabious while giving',
#  'free fabious while giving him',
#  'fabious while giving him the',
#  'while giving him the sword',
#  'giving him the sword of',
#  'him the sword of unicorn',
#  'the sword of unicorn as',
#  'sword of unicorn as the',
#  'of unicorn as the others',
#  'unicorn as the others kill',
#  'as the others kill off',
#  'the others kill off julie',
#  'others kill off julie and',
#  "kill off julie and boremont's",
#  "off julie and boremont's men",
#  "julie and boremont's men along",
#  "and boremont's men along with",
#  "boremont's men along with leezar's",
#  "men along with leezar's mothers",
#  "along with leezar's mothers fabious",
#  "with leezar's mothers fabious uses",
#  "leezar's mothers fabious uses the",
#  'mothers fabious uses the blade',
#  'fabious uses the blade of',
#  'uses the blade of unicorn',
#  'the blade of unicorn to',
#  'blade of unicorn to end',
#  "of unicorn to end leezar's",
#  "unicorn to end leezar's life",
#  "to end leezar's life before",
#  "end leezar's life before he",
#  "leezar's life before he can",
#  'life before he can rape',
#  'before he can rape belladonna',
#  'he can rape belladonna saving',
#  'can rape belladonna saving the',
#  'rape belladonna saving the kingdom',
#  'belladonna saving the kingdom after',
#  'saving the kingdom after their',
#  'the kingdom after their victory',
#  'kingdom after their victory isabel',
#  'after their victory isabel goes',
#  'their victory isabel goes on',
#  'victory isabel goes on another',
#  'isabel goes on another quest',
#  'goes on another quest and',
#  'on another quest and the',
#  'another quest and the heroes',
#  'quest and the heroes return',
#  'and the heroes return home',
#  'the heroes return home fabious',
#  'heroes return home fabious and',
#  'return home fabious and belladonna',
#  'home fabious and belladonna marry',
#  'fabious and belladonna marry thadeous',
#  'and belladonna marry thadeous is',
#  'belladonna marry thadeous is approached',
#  'marry thadeous is approached by',
#  'thadeous is approached by isabel',
#  'is approached by isabel who',
#  'approached by isabel who reveals',
#  'by isabel who reveals that',
#  'isabel who reveals that she',
#  'who reveals that she has',
#  'reveals that she has fallen',
#  'that she has fallen in',
#  'she has fallen in love',
#  'has fallen in love with',
#  'fallen in love with him',
#  'in love with him however',
#  'love with him however for',
#  'with him however for them',
#  'him however for them to',
#  'however for them to have',
#  'for them to have sex',
#  'them to have sex he',
#  'to have sex he must',
#  'have sex he must first',
#  'sex he must first slay',
#  'he must first slay the',
#  'must first slay the witch',
#  'first slay the witch that',
#  'slay the witch that cast',
#  'the witch that cast a',
#  'witch that cast a spell',
#  'that cast a spell on',
#  'cast a spell on her',
#  'a spell on her locking',
#  'spell on her locking her',
#  'on her locking her in',
#  'her locking her in a',
#  'locking her in a chastity',
#  'her in a chastity belt',
#  'in a chastity belt though',
#  'a chastity belt though he',
#  'chastity belt though he is',
#  'belt though he is not',
#  'though he is not in',
#  'he is not in the',
#  'is not in the mood',
#  'not in the mood to',
#  'in the mood to go',
#  'the mood to go out',
#  "mood to go out isabel's",
#  "to go out isabel's suggestion",
#  "go out isabel's suggestion convinces",
#  "out isabel's suggestion convinces him",
#  "isabel's suggestion convinces him to",
#  'suggestion convinces him to go',
#  'convinces him to go on',
#  'him to go on a',
#  'to go on a new',
#  'plot jung suji is a',
#  'jung suji is a quiet',
#  'suji is a quiet mysterious',
#  'is a quiet mysterious beauty',
#  'a quiet mysterious beauty whenever',
#  'quiet mysterious beauty whenever she',
#  'mysterious beauty whenever she speaks',
#  'beauty whenever she speaks to',
#  'whenever she speaks to nami',
#  'she speaks to nami it',
#  'speaks to nami it is',
#  'to nami it is always',
#  'nami it is always with',
#  'it is always with disdaintowards',
#  'is always with disdaintowards the',
#  'always with disdaintowards the end',
#  'with disdaintowards the end of',
#  'disdaintowards the end of the',
#  'the end of the film',
#  'end of the film nami',
#  'of the film nami confronts',
#  'the film nami confronts suji',
#  'film nami confronts suji and',
#  'nami confronts suji and learns',
#  'confronts suji and learns that',
#  'suji and learns that sujis',
#  'and learns that sujis stepmother',
#  'learns that sujis stepmother is',
#  'that sujis stepmother is from',
#  'sujis stepmother is from jeollado',
#  'stepmother is from jeollado the',
#  'is from jeollado the same',
#  'from jeollado the same city',
#  'jeollado the same city nami',
#  'the same city nami is',
#  'same city nami is from',
#  'city nami is from making',
#  'nami is from making suji',
#  'is from making suji automatically',
#  'from making suji automatically biased',
#  'making suji automatically biased against',
#  'suji automatically biased against nami',
#  'automatically biased against nami the',
#  'biased against nami the two',
#  'against nami the two make',
#  'nami the two make up',
#  'the two make up after',
#  'two make up after drinking',
#  'make up after drinking soju',
#  'up after drinking soju and',
#  'after drinking soju and crying',
#  'drinking soju and crying out',
#  'soju and crying out their',
#  'and crying out their frustrations',
#  'crying out their frustrations together',
#  'out their frustrations together nami',
#  'their frustrations together nami is',
#  'frustrations together nami is accepted',
#  'together nami is accepted into',
#  'nami is accepted into their',
#  'is accepted into their group',
#  'accepted into their group as',
#  'into their group as their',
#  'their group as their seventh',
#  'group as their seventh member',
#  'as their seventh member after',
#  'their seventh member after she',
#  'seventh member after she unexpectedly',
#  'member after she unexpectedly proves',
#  'after she unexpectedly proves herself',
#  'she unexpectedly proves herself against',
#  'unexpectedly proves herself against a',
#  'proves herself against a rival',
#  'herself against a rival group',
#  'against a rival group from',
#  'a rival group from a',
#  'rival group from a different',
#  'group from a different school',
#  'from a different school chiunhwa',
#  'a different school chiunhwa suggests',
#  'different school chiunhwa suggests naming',
#  'school chiunhwa suggests naming their',
#  'chiunhwa suggests naming their group',
#  'suggests naming their group they',
#  'naming their group they settle',
#  'their group they settle on',
#  'group they settle on sunny',
#  'they settle on sunny after',
#  'settle on sunny after a',
#  'on sunny after a nighttime',
#  'sunny after a nighttime radio',
#  'after a nighttime radio dj',
#  'a nighttime radio dj responds',
#  'nighttime radio dj responds to',
#  'radio dj responds to their',
#  'dj responds to their letter',
#  'responds to their letter on',
#  'to their letter on air',
#  'their letter on air back',
#  'letter on air back at',
#  'on air back at the',
#  'air back at the present',
#  'back at the present time',
#  'at the present time nami',
#  'the present time nami returns',
#  'present time nami returns to',
#  "time nami returns to chiunhwa's",
#  "nami returns to chiunhwa's room",
#  "returns to chiunhwa's room and",
#  "to chiunhwa's room and confirms",
#  "chiunhwa's room and confirms it",
#  'room and confirms it is',
#  'and confirms it is indeed',
#  'confirms it is indeed her',
#  'it is indeed her high',
#  'is indeed her high school',
#  'indeed her high school friend',
#  'her high school friend she',
#  'high school friend she learns',
#  'school friend she learns that',
#  'friend she learns that chiunhwa',
#  'she learns that chiunhwa became',
#  'learns that chiunhwa became a',
#  'that chiunhwa became a successful',
#  'chiunhwa became a successful businesswoman',
#  'became a successful businesswoman but',
#  'a successful businesswoman but has',
#  'successful businesswoman but has terminal',
#  'businesswoman but has terminal cancer',
#  'but has terminal cancer with',
#  'has terminal cancer with two',
#  'terminal cancer with two months',
#  'cancer with two months to',
#  'with two months to live',
#  'two months to live namis',
#  'months to live namis husband',
#  'to live namis husband calls',
#  'live namis husband calls and',
#  'namis husband calls and informs',
#  'husband calls and informs her',
#  'calls and informs her that',
#  'and informs her that he',
#  'informs her that he is',
#  'her that he is on',
#  'that he is on a',
#  'he is on a twomonth',
#  'is on a twomonth business',
#  'on a twomonth business trip',
#  'a twomonth business trip as',
#  'twomonth business trip as nami',
#  'business trip as nami leaves',
#  'trip as nami leaves she',
#  'as nami leaves she promises',
#  'nami leaves she promises she',
#  'leaves she promises she will',
#  'she promises she will visit',
#  'promises she will visit often',
#  'she will visit often chiunhwa',
#  'will visit often chiunhwa then',
#  'visit often chiunhwa then tells',
#  'often chiunhwa then tells her',
#  'chiunhwa then tells her she',
#  'then tells her she would',
#  'tells her she would like',
#  'her she would like to',
#  'she would like to see',
#  'would like to see sunny',
#  'like to see sunny reunited',
#  'to see sunny reunited one',
#  'see sunny reunited one more',
#  'sunny reunited one more time',
#  'reunited one more time before',
#  'one more time before she',
#  'more time before she diesref',
#  'time before she diesref nameseptember',
#  'before she diesref nameseptember reasondo',
#  'she diesref nameseptember reasondo they',
#  'diesref nameseptember reasondo they reunite',
#  'nameseptember reasondo they reunite before',
#  'reasondo they reunite before the',
#  'they reunite before the funeral',
#  'reunite before the funeral or',
#  'before the funeral or at',
#  'the funeral or at the',
#  'funeral or at the funeral',
#  'or at the funeral at',
#  "at the funeral at chiunhwa's",
#  "the funeral at chiunhwa's funeral",
#  "funeral at chiunhwa's funeral sunny",
#  "at chiunhwa's funeral sunny is",
#  "chiunhwa's funeral sunny is reunited",
#  'funeral sunny is reunited but',
#  'sunny is reunited but not',
#  'is reunited but not every',
#  'reunited but not every woman',
#  'but not every woman knows',
#  'not every woman knows about',
#  'every woman knows about each',
#  "woman knows about each other's",
#  "knows about each other's present",
#  "about each other's present struggles",
#  "each other's present struggles as",
#  "other's present struggles as they",
#  'present struggles as they are',
#  'struggles as they are about',
#  'as they are about to',
#  'they are about to leave',
#  "are about to leave chiunhwa's",
#  "about to leave chiunhwa's lawyer",
#  "to leave chiunhwa's lawyer walks",
#  "leave chiunhwa's lawyer walks in",
#  "chiunhwa's lawyer walks in and",
#  'lawyer walks in and asks',
#  'walks in and asks them',
#  'in and asks them if',
#  'and asks them if they',
#  'asks them if they are',
#  'them if they are sunny',
#  'if they are sunny he',
#  'they are sunny he reads',
#  "are sunny he reads chiunhwa's",
#  "sunny he reads chiunhwa's will",
#  "he reads chiunhwa's will which",
#  "reads chiunhwa's will which bequeathes",
#  "chiunhwa's will which bequeathes that",
#  'will which bequeathes that nami',
#  'which bequeathes that nami will',
#  'bequeathes that nami will be',
#  ...]

# %% [markdown]
# * map word to integer value

# %%
# create integer-to-token mapping
int2token = {}
cnt = 0

for w in set(" ".join(movie_plots).split()):
  int2token[cnt] = w
  cnt+= 1

# create token-to-integer mapping
token2int = {t: i for i, t in int2token.items()}

token2int["the"], int2token[14271]
# Out:
# (4522, "tsumun's")

# %%
# set vocabulary size
vocab_size = len(int2token)
vocab_size
# Out:
# 16592

# %% [markdown]
# * 위에서 integer로 변환했으니, seq 들을 integer seq로 변환

# %%
def get_integer_seq(seq):
  return [token2int[w] for w in seq.split()]

# convert text sequences to integer sequences
x_int = [get_integer_seq(i) for i in x]
y_int = [get_integer_seq(i) for i in y]

# convert lists to numpy arrays
x_int = np.array(x_int)
y_int = np.array(y_int)

# %%
x_int
# Out:
# array([[ 3357,  6590,  9234,  6256,  7246],
#        [ 6590,  9234,  6256,  7246,  4522],
#        [ 9234,  6256,  7246,  4522,  3408],
#        ...,
#        [ 2108, 12494,  2646,  6784,  1901],
#        [12494,  2646,  6784,  1901, 11917],
#        [ 2646,  6784,  1901, 11917,  5082]])

# %%
from transformers import BartForConditionalGeneration

# %%
net = BartForConditionalGeneration.from_pretrained("facebook/bart-large", force_bos_token_to_be_generated=True)

# %%
net.cuda()
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(50265, 1024, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024, padding_idx=1)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024, padding_idx=1)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=50265, bias=False)
# )

# %%
def train(net, epochs=10, batch_size=32, lr=0.001, clip=1, print_every=32):
    
    # optimizer
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    
    # loss
    criterion = nn.CrossEntropyLoss()
    
    # push model to GPU
    net.cuda()
    
    counter = 0

    net.train()

    for e in range(epochs):

        # initialize hidden state
        h = net.init_hidden(batch_size)
        
        for x, y in get_batches(x_int, y_int, batch_size):
            counter+= 1
            
            # convert numpy arrays to PyTorch arrays
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            
            # push tensors to GPU
            inputs, targets = inputs.cuda(), targets.cuda()

            # detach hidden states
            h = tuple([each.data for each in h])

            # zero accumulated gradients
            net.zero_grad()
            
            # get the output from the model
            output, h = net(inputs, h)
            
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(-1))

            # back-propagate error
            loss.backward()

            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            # update weigths
            opt.step()            
            
            if counter % print_every == 0:
            
              print("Epoch: {}/{}...".format(e+1, epochs),
                    "Step: {}...".format(counter))

# %%
# predict next token
def predict(net, tkn, h=None):
         
  # tensor inputs
  x = np.array([[token2int[tkn]]])
  inputs = torch.from_numpy(x)
  
  # push to GPU
  inputs = inputs.cuda()

  # detach hidden state from history
  h = tuple([each.data for each in h])

  # get the output of the model
  out, h = net(inputs, h)

  # get the token probabilities
  p = F.softmax(out, dim=1).data

  p = p.cpu()

  p = p.numpy()
  p = p.reshape(p.shape[1],)

  # get indices of top 3 values
  top_n_idx = p.argsort()[-3:][::-1]

  # randomly select one of the three indices
  sampled_token_index = top_n_idx[random.sample([0,1,2],1)[0]]

  # return the encoded value of the predicted char and the hidden state
  return int2token[sampled_token_index], h


# function to generate text
def sample(net, size, prime='it is'):
        
    # push to GPU
    net.cuda()
    
    net.eval()

    # batch size is 1
    h = net.init_weights()

    toks = prime.split()

    # predict next token
    for t in prime.split():
      token, h = predict(net, t, h)
    
    toks.append(token)

    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], h)
        toks.append(token)

    return ' '.join(toks)

# %%
sample(net, 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-9500cb446045> in <module>
# ----> 1 sample(net, 15)
#
# <ipython-input-31-00b8923b6f9e> in sample(net, size, prime)
#      48     # predict next token
#      49     for t in prime.split():
# ---> 50       token, h = predict(net, t, h)
#      51
#      52     toks.append(token)
#
# <ipython-input-31-00b8923b6f9e> in predict(net, tkn, h)
#      10
#      11   # detach hidden state from history
# ---> 12   h = tuple([each.data for each in h])
#      13
#      14   # get the output of the model
#
# TypeError: 'NoneType' object is not iterable
